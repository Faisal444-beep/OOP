# %%
# prompt: object oriented programe

class Student:
    college_name = "Adamjee college"
    def __init__(self,name,fathername,age,standard,marks):
        self.name = name
        self.fathername = fathername
        self.age = age
        self.standard = standard
        self.marks = marks
    def Welcome(self):
        print("Welcome Student",self.name)
    def get_marks(self):
        return self.marks
s1 = Student("faisal","farooque",28,"developer",98)
s2 = Student("ahmed","bilal",29,"developer",88)
s3 = Student("yousuf","khan",29,"developer",78)
# Calling the methods correctly:
print(s1.name,s1.age,s1.standard,s1.get_marks())
print(s2.name,s2.age,s2.standard,s2.get_marks())
print(s3.name,s3.age,s3.standard,s3.get_marks())
# Moved these lines outside the class definition
s1 = Student("faisal","farooque",28,"developer",98)
s2 = Student("ahmed","bilal",29,"developer",88)
s3 = Student("yousuf","khan",29,"developer",78)
# Out:
# faisal 28 developer 98
# ahmed 29 developer 88
# yousuf 29 developer 78
